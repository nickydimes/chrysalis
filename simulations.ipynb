# %% [markdown]
# # Universality and Criticality: The Chrysalis Simulations
#
# This notebook runs five computational models that demonstrate **universality** — the remarkable phenomenon where systems with completely different microscopic dynamics exhibit identical behavior at their critical points.
#
# Each simulation sweeps a control parameter through a phase transition and measures:
# - **Order parameter**: what emerges (magnetization, cluster size, neural activity)
# - **Susceptibility**: how responsive the system is to perturbation
# - **Scaling exponents**: the universal fingerprint of the transition
#
# The systems span physics and neuroscience, yet share the same mathematical structure at criticality. This is the core claim of the Chrysalis framework: transformation dynamics are universal.
#
# ---

# %%
# Run all five simulations (generates PNG output files)
# Each takes ~10-30 seconds depending on lattice size

# %run simulations/phase_transitions/ising_2d.py
# %run simulations/phase_transitions/potts_2d.py
# %run simulations/phase_transitions/percolation_2d.py
# %run simulations/phase_transitions/xy_2d.py --N 16 --eq_sweeps 100 --meas_sweeps 200
# %run simulations/neuroscience/critical_brain.py

# %% [markdown]
# ## 1. Ising Model (Z₂ Symmetry Breaking)
#
# The 2D Ising model is the simplest system exhibiting a continuous phase transition. Binary spins on a square lattice interact ferromagnetically. At the **Onsager critical temperature** T_c ≈ 2.269 J/k_B:
#
# - Below T_c: spins align spontaneously → **magnetization** emerges (symmetry breaking)
# - At T_c: the system is scale-invariant — fluctuations of all sizes coexist
# - Above T_c: thermal noise destroys order → paramagnetic phase
#
# **Exact exponents**: β/ν = 1/8, γ/ν = 7/4, ν = 1

# %%
from IPython.display import Image, display
display(Image('simulations/phase_transitions/ising_results.png', width=900))
display(Image('simulations/phase_transitions/ising_scaling.png', width=900))

# %% [markdown]
# ---
#
# ## 2. Potts Model (Z₃ Symmetry Breaking)
#
# The q=3 Potts model generalizes Ising from 2 states to 3. Each spin can point in one of three directions. Neighbors interact when they share the same state. This puts the system in a **different universality class**.
#
# **Exact exponents**: β/ν = 2/15, γ/ν = 26/15, ν = 5/6, T_c ≈ 0.995

# %%
display(Image('simulations/phase_transitions/potts_results.png', width=900))
display(Image('simulations/phase_transitions/potts_scaling.png', width=900))

# %% [markdown]
# ---
#
# ## 3. Percolation (Geometric Phase Transition)
#
# Site percolation is purely geometric: each lattice site is independently occupied with probability p. At the **percolation threshold** p_c ≈ 0.5927, a giant spanning cluster first appears.
#
# **Exact exponents**: β/ν = 5/48, γ/ν = 43/24, ν = 4/3, τ = 187/91

# %%
display(Image('simulations/phase_transitions/percolation_results.png', width=900))
display(Image('simulations/phase_transitions/percolation_scaling.png', width=900))

# %% [markdown]
# ---
#
# ## 4. XY Model (Topological BKT Transition)
#
# The 2D XY model features continuous O(2) symmetry. Unlike discrete models, it has no long-range order at finite T. Instead, it exhibits a **topological transition** (Berezinskii-Kosterlitz-Thouless) at T_BKT ≈ 0.89.
#
# - **Below T_BKT**: Vortex-antivortex pairs are bound. The system is "stiff" (Helicity modulus > 0).
# - **Above T_BKT**: Topological defects unbind, destroying the quasi-long-range order.
#
# **Key signature**: A universal jump in the helicity modulus (stiffness) from 2/π * T_BKT to zero.

# %%
display(Image('simulations/phase_transitions/xy_results.png', width=900))

# %% [markdown]
# ---
#
# ## 5. Critical Brain (Neural Branching Process)
#
# This neural branching process grid simulates activity propagation. The **critical brain hypothesis** proposes that healthy neural systems operate near σ_c = 1.0, balancing sensitivity and stability.
#
# **Mean-field exponents**: P(s) ~ s^{-3/2}, P(d) ~ d^{-2}, γ_sd = 2

# %%
display(Image('simulations/neuroscience/critical_brain_results.png', width=900))
display(Image('simulations/neuroscience/critical_brain_scaling.png', width=900))

# %% [markdown]
# ---
#
# ## Universality Summary
#
# | System | Symmetry | Control parameter | Critical Point | Topological Defects |
# |--------|----------|-------------------|----------------|---------------------|
# | Ising | Z₂ | Temperature T | T_c ≈ 2.269 | Domain walls |
# | Potts | Z₃ | Temperature T | T_c ≈ 0.995 | Domain walls |
# | Percolation | Geometric | Probability p | p_c ≈ 0.5927 | N/A |
# | XY Model | O(2) | Temperature T | T_BKT ≈ 0.89 | Vortices |
# | Brain | Branching | Branching ratio σ | σ_c = 1.0 | Avalanches |
#
# The Chrysalis framework leverages these universal patterns to study transitions in complex sociocultural systems, where the "Eight-Step Navigation Protocol" maps directly onto these phase change dynamics.
